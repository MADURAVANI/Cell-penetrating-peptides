# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from joblib import dump, load
from sklearn.metrics import accuracy_score

# %%
X_positives = pd.read_csv("./cpp_positive_training.csv")
X_negatives = pd.read_csv("./cpp_negative_training.csv")
y_positives = np.ones(len(X_positives))
y_negatives = np.zeros(len(X_negatives))

frames = [X_positives, X_negatives]
X = pd.concat(frames)

y = np.concatenate((y_positives, y_negatives), axis = None)
print(y.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle = True)
# Out:
# (1146,)

# %%
svm_model = load('svm_aac.joblib')

# %%
from sbs import SequentialBackwardSelection

sbs_svm = SequentialBackwardSelection(estimator=svm_model,
                                      min_features=2,
                                      scoring_metric=accuracy_score,
                                      scale_features = False)

sbs_svm.fit(X_train, X_test, y_train, y_test)
# Out:
# Removed feature: AAC_E
# Current performance: 0.84783
# Remaining features: ['AAC_A', 'AAC_C', 'AAC_D', 'AAC_F', 'AAC_G', 'AAC_H', 'AAC_I', 'AAC_K', 'AAC_L', 'AAC_M', 'AAC_N', 'AAC_P', 'AAC_Q', 'AAC_R', 'AAC_S', 'AAC_T', 'AAC_V', 'AAC_W', 'AAC_Y']
#
#
# Removed feature: AAC_H
# Current performance: 0.85652
# Remaining features: ['AAC_A', 'AAC_C', 'AAC_D', 'AAC_F', 'AAC_G', 'AAC_I', 'AAC_K', 'AAC_L', 'AAC_M', 'AAC_N', 'AAC_P', 'AAC_Q', 'AAC_R', 'AAC_S', 'AAC_T', 'AAC_V', 'AAC_W', 'AAC_Y']
#
#
# Removed feature: AAC_N
# Current performance: 0.86087
# Remaining features: ['AAC_A', 'AAC_C', 'AAC_D', 'AAC_F', 'AAC_G', 'AAC_I', 'AAC_K', 'AAC_L', 'AAC_M', 'AAC_P', 'AAC_Q', 'AAC_R', 'AAC_S', 'AAC_T', 'AAC_V', 'AAC_W', 'AAC_Y']
#
#
# Removed feature: AAC_G
# Current performance: 0.86957
# Remaining features: ['AAC_A', 'AAC_C', 'AAC_D', 'AAC_F', 'AAC_I', 'AAC_K', 'AAC_L', 'AAC_M', 'AAC_P', 'AAC_Q', 'AAC_R', 'AAC_S', 'AAC_T', 'AAC_V', 'AAC_W', 'AAC_Y']
#
#
# Removed feature: AAC_V
# ...
